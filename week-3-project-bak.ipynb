# %% [markdown]
# # Toronto Neighborhoods

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd
from geopy.geocoders import Nominatim
import folium

# %% [markdown]
# will use 'https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Toronto'

# %%
url = 'https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Toronto'
result = requests.get(url)
print(url)
print(result.status_code)
print(result.headers)
# Out:
# https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Toronto
# 200
# {'Date': 'Sat, 22 Dec 2018 03:46:16 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Content-Length': '30805', 'Connection': 'keep-alive', 'Server': 'mw1333.eqiad.wmnet', 'X-Content-Type-Options': 'nosniff', 'P3P': 'CP="This is not a P3P policy! See https://en.wikipedia.org/wiki/Special:CentralAutoLogin/P3P for more info."', 'X-Powered-By': 'HHVM/3.18.6-dev', 'Content-language': 'en', 'Last-Modified': 'Thu, 20 Dec 2018 23:29:00 GMT', 'Backend-Timing': 'D=122113 t=1545353436381943', 'Vary': 'Accept-Encoding,Cookie,Authorization,X-Seven', 'Content-Encoding': 'gzip', 'X-Varnish': '48425371 448736211, 338387129 716564982', 'Via': '1.1 varnish (Varnish/5.1), 1.1 varnish (Varnish/5.1)', 'Age': '96938', 'X-Cache': 'cp1079 hit/9, cp1075 hit/15', 'X-Cache-Status': 'hit-front', 'Server-Timing': 'cache;desc="hit-front"', 'Strict-Transport-Security': 'max-age=106384710; includeSubDomains; preload', 'Set-Cookie': 'WMF-Last-Access=22-Dec-2018;Path=/;HttpOnly;secure;Expires=Wed, 23 Jan 2019 00:00:00 GMT, WMF-Last-Access-Global=22-Dec-2018;Path=/;Domain=.wikipedia.org;HttpOnly;secure;Expires=Wed, 23 Jan 2019 00:00:00 GMT, GeoIP=US:IL:Barrington:42.16:-88.14:v4; Path=/; secure; Domain=.wikipedia.org', 'X-Analytics': 'ns=0;page_id=1150939;https=1;nocookies=1', 'X-Client-IP': '73.72.63.152', 'Cache-Control': 'private, s-maxage=0, max-age=0, must-revalidate', 'Accept-Ranges': 'bytes'}

# %%
# define the dataframe
df = pd.DataFrame(columns=['Hood', 'Latitude', 'Longitude'])
df.head()
# Out:
# Empty DataFrame
# Columns: [Hood, Latitude, Longitude]
# Index: []

# %% [markdown]
# get data + clean it

# %%
soup = BeautifulSoup(result.content, 'html.parser')
table = soup.find('table')
lis = table.find_all('li')

list_of_n = []
for li in lis:
    a = li.find('a')
    list_of_n.append(a.get('title').split(", ")[0].split(" (neighbourhood)")[0].split(" (Toronto)")[0] )

# %% [markdown]
# will start populating the dataframe with hood names

# %%
df['Hood'] = pd.Series(list_of_n)
print(df.shape)
df.head()
# Out:
# (89, 3)
#               Hood Latitude Longitude
# 0   Alexandra Park      NaN       NaN
# 1        The Annex      NaN       NaN
# 2  Baldwin Village      NaN       NaN
# 3      Cabbagetown      NaN       NaN
# 4        CityPlace      NaN       NaN

# %% [markdown]
# duplicates?

# %%
df.drop_duplicates(inplace=True)
print(df.shape)
df.head()
# Out:
# (86, 3)
#               Hood Latitude Longitude
# 0   Alexandra Park      NaN       NaN
# 1        The Annex      NaN       NaN
# 2  Baldwin Village      NaN       NaN
# 3      Cabbagetown      NaN       NaN
# 4        CityPlace      NaN       NaN

# %% [markdown]
# loop over to get coordinates and populate the df
# need to drop those hoods that the geo does not find

# %%
to_drop_unknown = []
geolocator = Nominatim(user_agent="coursera")
for index, row in df.iterrows():
    address = row['Hood'] + ', Toronto'
    try:
        location = geolocator.geocode(address)
        latitude = location.latitude
        longitude = location.longitude
        print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
        df.loc[index, 'Latitude'] = latitude
        df.loc[index, 'Longitude'] = longitude
    except AttributeError:
        print('Cannot do: {}, will drop index: {}'.format(address, index))
        to_drop_unknown.append(index)

df.head()
# Out:
# The geograpical coordinate of Alexandra Park, Toronto are 43.65075755, -79.4042978683821.
# The geograpical coordinate of The Annex, Toronto are 43.6703377, -79.407117.
# The geograpical coordinate of Baldwin Village, Toronto are 43.66981815, -79.4971720343184.
# The geograpical coordinate of Cabbagetown, Toronto are 43.6644734, -79.3669861.
# The geograpical coordinate of CityPlace, Toronto are 43.6392482, -79.3963865.
# The geograpical coordinate of Chinatown, Toronto are 43.6529237, -79.3980316.
# The geograpical coordinate of Church and Wellesley, Toronto are 43.6655242, -79.3838011.
# The geograpical coordinate of Corktown, Toronto are 43.6573709, -79.3565189.
# The geograpical coordinate of Discovery District, Toronto are 43.6575555, -79.3894803.
# The geograpical coordinate of Distillery District, Toronto are 43.6502803, -79.3595767.
# The geograpical coordinate of Toronto Entertainment District, Toronto are 43.64383755, -79.3866924741406.
# Cannot do: East Bayfront, Toronto, will drop index: 11
# The geograpical coordinate of Fashion District, Toronto are 43.6454561, -79.3949942.
# The geograpical coordinate of Financial District, Toronto are 43.64866395, -79.3815338905095.
# The geograpical coordinate of Garden District, Toronto are 43.6565019, -79.3771275.
# The geograpical coordinate of Grange Park, Toronto are 43.65214745, -79.3922649889305.
# The geograpical coordinate of Harbord Village, Toronto are 43.6615225, -79.4097446.
# The geograpical coordinate of Harbourfront, Toronto are 43.6400801, -79.3801495.
# The geograpical coordinate of Kensington Market, Toronto are 43.6552136, -79.4022604.
# Cannot do: Little Japan, Toronto, will drop index: 19
# The geograpical coordinate of Moss Park, Toronto are 43.6546438, -79.3697278.
# The geograpical coordinate of Old Town, Toronto are 43.6708625, -79.3727924125372.
# The geograpical coordinate of Quayside, Toronto are 43.6472502, -79.3581720783773.
# The geograpical coordinate of Queen Street West, Toronto are 43.6405606, -79.4367827.
# The geograpical coordinate of Regent Park, Toronto are 43.6607056, -79.3604569.
# The geograpical coordinate of South Core, Toronto are 43.6421064, -79.3774455.
# The geograpical coordinate of St. James Town, Toronto are 43.6694032, -79.3727041.
# The geograpical coordinate of St. Lawrence, Toronto are 43.649422, -79.3714278.
# The geograpical coordinate of Toronto Islands, Toronto are 43.6161962, -79.3693582.
# The geograpical coordinate of Trefann Court, Toronto are 43.6564893, -79.3628297.
# The geograpical coordinate of University of Toronto, Toronto are 43.66333345, -79.3976997498952.
# The geograpical coordinate of Yorkville, Toronto are 43.6713861, -79.3901677.
# The geograpical coordinate of The Beaches, Toronto are 43.6710244, -79.296712.
# The geograpical coordinate of East Danforth, Toronto are 43.6863598, -79.3003158.
# The geograpical coordinate of Gerrard Street, Toronto are 43.6695453, -79.3356133.
# Cannot do: Greektown, Toronto, will drop index: 35
# The geograpical coordinate of Leslieville, Toronto are 43.6627, -79.3328148.
# The geograpical coordinate of Main Square, Toronto are 43.68774405, -79.3004609737296.
# Cannot do: Playter Estates, Toronto, will drop index: 38
# The geograpical coordinate of Port Lands, Toronto are 43.6430648, -79.3506012.
# The geograpical coordinate of Riverdale, Toronto are 43.6654704, -79.3525936.
# The geograpical coordinate of Upper Beaches, Toronto are 43.6710244, -79.296712.
# The geograpical coordinate of Bedford Park, Toronto are 43.7373876, -79.4109253.
# The geograpical coordinate of Casa Loma, Toronto are 43.67811065, -79.4094082263767.
# The geograpical coordinate of Chaplin Estates, Toronto are 43.7025981, -79.4032704.
# The geograpical coordinate of Davisville Village, Toronto are 43.7043123, -79.3885169.
# The geograpical coordinate of Deer Park, Toronto are 43.68809, -79.3940935.
# The geograpical coordinate of Forest Hill, Toronto are 43.6935586, -79.4139023.
# The geograpical coordinate of Lawrence Park, Toronto are 43.729199, -79.4032525.
# The geograpical coordinate of Lytton Park, Toronto are 43.7159986, -79.412291.
# The geograpical coordinate of Midtown, Toronto are 43.7051999, -79.3974155214733.
# The geograpical coordinate of Moore Park, Toronto are 43.6903876, -79.3832965.
# The geograpical coordinate of North Toronto, Toronto are 43.653963, -79.387207.
# The geograpical coordinate of Rosedale, Toronto are 43.6764534, -79.3884341.
# The geograpical coordinate of South Hill, Toronto are 43.6779261, -79.4057671.
# The geograpical coordinate of Summerhill, Toronto are 43.6816776, -79.3905037.
# The geograpical coordinate of Wanless Park, Toronto are 43.7289408, -79.3920274498931.
# The geograpical coordinate of Wychwood Park, Toronto are 43.677743, -79.4201849779446.
# The geograpical coordinate of Yonge–Eglinton, Toronto are 43.7067479, -79.3983271.
# The geograpical coordinate of Little Portugal, Toronto are 43.6496309, -79.4314332.
# The geograpical coordinate of Bloor West Village, Toronto are 43.6493184, -79.4844358.
# The geograpical coordinate of Bracondale Hill, Toronto are 43.6761247, -79.4279997.
# The geograpical coordinate of Brockton Village, Toronto are 43.6509891, -79.440029.
# The geograpical coordinate of Carleton Village, Toronto are 43.6707205, -79.4532778.
# The geograpical coordinate of Corso Italia, Toronto are 43.677954, -79.4430828.
# The geograpical coordinate of Davenport, Toronto are 43.6749283, -79.3938683710768.
# The geograpical coordinate of Dovercourt Park, Toronto are 43.6651844, -79.433504844005.
# The geograpical coordinate of Dufferin Grove, Toronto are 43.6536156, -79.4263889.
# The geograpical coordinate of Earlscourt, Toronto are 43.6762773, -79.4505723.
# The geograpical coordinate of Fort York, Toronto are 43.6386801, -79.4035012349971.
# The geograpical coordinate of High Park North, Toronto are 43.64628135, -79.4638213811953.
# The geograpical coordinate of The Junction, Toronto are 43.6654775, -79.470352.
# The geograpical coordinate of Junction Triangle, Toronto are 43.6654775, -79.470352.
# The geograpical coordinate of Koreatown, Toronto are 43.6635564, -79.4184157.
# The geograpical coordinate of Liberty Village, Toronto are 43.6388951, -79.4179531.
# The geograpical coordinate of Little Italy, Toronto are 43.6552079, -79.4148769.
# The geograpical coordinate of Little Tibet, Toronto are 43.6389445, -79.4273119.
# The geograpical coordinate of Palmerston–Little Italy, Toronto are 43.6558789, -79.4100759.
# The geograpical coordinate of Niagara, Toronto are 43.6446581, -79.409207.
# The geograpical coordinate of Parkdale, Toronto are 43.6371777, -79.4360045.
# The geograpical coordinate of Roncesvalles, Toronto are 43.63966125, -79.4478000818224.
# The geograpical coordinate of Runnymede, Toronto are 43.6655802, -79.4821078.
# The geograpical coordinate of Seaton Village, Toronto are 43.6692756, -79.4159596.
# The geograpical coordinate of Swansea, Toronto are 43.64494, -79.478313.
# The geograpical coordinate of Trinity–Bellwoods, Toronto are 43.64762725, -79.4138792590604.
# The geograpical coordinate of Wallace Emerson, Toronto are 43.6667328, -79.4464779.
#               Hood Latitude Longitude
# 0   Alexandra Park  43.6508  -79.4043
# 1        The Annex  43.6703  -79.4071
# 2  Baldwin Village  43.6698  -79.4972
# 3      Cabbagetown  43.6645   -79.367
# 4        CityPlace  43.6392  -79.3964

# %%
clean_df = df.drop(to_drop_unknown)

# %%
clean_df.shape
# Out:
# (82, 3)

# %% [markdown]
# mapping time

# %%
address = 'Toronto'
try:
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    print('The geograpical coordinate of {} are {}, {}.'.format(address, latitude, longitude))
    df.loc[index, 'Latitude'] = latitude
    df.loc[index, 'Longitude'] = longitude
except AttributeError:
    print('Cannot do: {}, will drop index: {}'.format(address, index))

my_map = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(clean_df['Latitude'], clean_df['Longitude'], clean_df['Hood']):
    label = folium.Popup(label)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(my_map)  
    
my_map
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
