# %% [markdown]
# ### Obtain data from Wiki Page

# %%
import pandas as pd
import wikipedia as wp
# Out:
# Collecting wikipedia
#   Downloading https://files.pythonhosted.org/packages/67/35/25e68fbc99e672127cc6fbb14b8ec1ba3dfef035bf1e4c90f78f24a80b7d/wikipedia-1.4.0.tar.gz
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/lib/python3.6/site-packages (from wikipedia) (4.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /home/jupyterlab/conda/lib/python3.6/site-packages (from wikipedia) (2.20.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.23)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.7)
# Building wheels for collected packages: wikipedia
#   Running setup.py bdist_wheel for wikipedia ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/87/2a/18/4e471fd96d12114d16fe4a446d00c3b38fb9efcb744bd31f4a
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0

# %%
# Get the table from wiki page
html = wp.page("List of postal codes of Canada: M").html().encode("UTF-8")
df = pd.read_html(html, header = 0)[0]

# Drope the rows with Borough of "Not assigned"
df_assigned = df[df.Borough != 'Not assigned']
df_assigned.reset_index(drop = True, inplace = True)

# Merge rows with the same Postcode
df_assigned = df_assigned.groupby(['Postcode', 'Borough'], as_index=False).agg(lambda x: ', '.join(set(x)))

# Set 'Not assigned' Neigbourhood to be equal to Borough
na_nb_idx =df_assigned['Neighbourhood'] == 'Not assigned'
df_assigned.loc[na_nb_idx, 'Neighbourhood'] = df_assigned[na_nb_idx].Borough
df_assigned[df_assigned['Postcode'] == 'M7A']
# Out:
#    Postcode       Borough Neighbourhood
# 85      M7A  Queen's Park  Queen's Park

# %%
# Show the shape of the df
df_assigned.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Add latitude and longitude of each neighborhood

# %%
# Since it is not able to obtain coordinates from using geocoder.google, the given csv file is used
# !wget -O GeoCord.csv http://cocl.us/Geospatial_data/
# Out:
# --2019-01-03 07:45:45--  http://cocl.us/Geospatial_data/
# Resolving cocl.us (cocl.us)... 169.48.113.201
# Connecting to cocl.us (cocl.us)|169.48.113.201|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data/ [following]
# --2019-01-03 07:45:45--  https://cocl.us/Geospatial_data/
# Connecting to cocl.us (cocl.us)|169.48.113.201|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-01-03 07:45:46--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.25.197, 107.152.24.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.25.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2019-01-03 07:45:47--  https://ibm.ent.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.26.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.26.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!qua8zNTevdJv4NFFL5uSeqP-HdzwjtInjREA-As-1J0_I3eoSts1ya4Oz-347uwkudgnioX9BfXzRmWYTMF_7pvH2JXwwshp1T3kaWOfcBwhdHNXLpnfuVdOgqS4HmaWNsiKze8UuFp90Tt9nKcbxckoL2WLfv-9PJ5d4KHmHoCeehvRzRRas7jod_EvGeWhUGU_hdI2Gn0ZHAg3GheUI_536dijMkUUaqHoVjuX_VGqHHjEDug-03-qY0BvGloY5Y6B3vu6RvKf93JS2pUngJwVcez2AnQL0147DPEWqiWkZjr3DEaBG_tY7lKmC9ZSZyVb45DgZPiRHVj4nTfdCB1C7EXq5-Q6yU2MCFTVJsKPQHP_cTEsE7IP_5V1sf1iEX-FZVknJwduxke0UciZDd3omzbGPAA1yGxQGgkZ66oJYhdihXrb0JVaXvd45OGdXlZFOX1aNOmVob5DxEf4tmPkUYEd0_sPDo4LnnPHXfjMWVtlvxzTWLl4nSWKAzOuGRvWu6cCIj99x37fNxU-BEeB8VKP-_qg7o2lb1B_X_IRmrBqlfyJaCX-GTFN2ZokgKPCtgsCB5_VY_TlUotjzNLiTPb8Eh3a7BTsVgGQCzUnPnRISQqU2kvk1xN0VfuiBCGAhWUR3lV7ExbBHR4kYN00hBaMYBIKtWoKZxQ4SFBPVzuGEstOKPeiLb9LKTHn52XmaTK0QWBfJuPNpOfcFu58n2KQc_1-mWtfNrHg_u--adok8d_DiNtR70i9fRucdbCKXyMxIQkk3d8vUtD4aO4A5oGuKFoQhf-KUxY4QUk7UyGYPLVLQxsa09es7-M3-O_QC_AeAD9-5p3xEJcZGkMlBblYLBXWxMVgS8YxbiRTmxmhUJOt5rCd3mFpdnnAFTYa5pBxuQynbdNPktjA3uV_0VQoDadvG5A5V6csfmPKl3jqckFkrM7MNQnCgvNl5CIJZoywJg_59i_i9LJFMytuG7sOvznQMkNMmSVnIHNJ-PfohIx2IfHYU6vFrD4rbHz-2112juQ_HvXMYqkYn-EMSU-c6SgWtyXqCheU81CDpEbldu4kkw-bg39of_39e1N8EMkSVYCeHYfEhNPpZnbdiBTf90acxp-nLef5TPnOYy9VPtUyFFHr8NQMLAEjSwWWMXCfGPZh-dR5pxAQKYCWNuczuv1usm0ntdqpSs57LvyuxXahAguymMyIoWHU__96GZaEWuVfFrpkz__tetFAQZtotgeGlAE7OAOgGMYRHpc12gud5AK_iaV4If_CpD4ymrGZGv_EvcTcNeiyj9GPLkh54cKc5AH3uHcjR0mttbpVDWhqb_C4cciwKv1YczqGwAKsNOLZTzj1hs-hws7m5pY1TVuIW8WXWL-2nYS4FM9U/download [following]
# --2019-01-03 07:45:47--  https://public.boxcloud.com/d/1/b1!qua8zNTevdJv4NFFL5uSeqP-HdzwjtInjREA-As-1J0_I3eoSts1ya4Oz-347uwkudgnioX9BfXzRmWYTMF_7pvH2JXwwshp1T3kaWOfcBwhdHNXLpnfuVdOgqS4HmaWNsiKze8UuFp90Tt9nKcbxckoL2WLfv-9PJ5d4KHmHoCeehvRzRRas7jod_EvGeWhUGU_hdI2Gn0ZHAg3GheUI_536dijMkUUaqHoVjuX_VGqHHjEDug-03-qY0BvGloY5Y6B3vu6RvKf93JS2pUngJwVcez2AnQL0147DPEWqiWkZjr3DEaBG_tY7lKmC9ZSZyVb45DgZPiRHVj4nTfdCB1C7EXq5-Q6yU2MCFTVJsKPQHP_cTEsE7IP_5V1sf1iEX-FZVknJwduxke0UciZDd3omzbGPAA1yGxQGgkZ66oJYhdihXrb0JVaXvd45OGdXlZFOX1aNOmVob5DxEf4tmPkUYEd0_sPDo4LnnPHXfjMWVtlvxzTWLl4nSWKAzOuGRvWu6cCIj99x37fNxU-BEeB8VKP-_qg7o2lb1B_X_IRmrBqlfyJaCX-GTFN2ZokgKPCtgsCB5_VY_TlUotjzNLiTPb8Eh3a7BTsVgGQCzUnPnRISQqU2kvk1xN0VfuiBCGAhWUR3lV7ExbBHR4kYN00hBaMYBIKtWoKZxQ4SFBPVzuGEstOKPeiLb9LKTHn52XmaTK0QWBfJuPNpOfcFu58n2KQc_1-mWtfNrHg_u--adok8d_DiNtR70i9fRucdbCKXyMxIQkk3d8vUtD4aO4A5oGuKFoQhf-KUxY4QUk7UyGYPLVLQxsa09es7-M3-O_QC_AeAD9-5p3xEJcZGkMlBblYLBXWxMVgS8YxbiRTmxmhUJOt5rCd3mFpdnnAFTYa5pBxuQynbdNPktjA3uV_0VQoDadvG5A5V6csfmPKl3jqckFkrM7MNQnCgvNl5CIJZoywJg_59i_i9LJFMytuG7sOvznQMkNMmSVnIHNJ-PfohIx2IfHYU6vFrD4rbHz-2112juQ_HvXMYqkYn-EMSU-c6SgWtyXqCheU81CDpEbldu4kkw-bg39of_39e1N8EMkSVYCeHYfEhNPpZnbdiBTf90acxp-nLef5TPnOYy9VPtUyFFHr8NQMLAEjSwWWMXCfGPZh-dR5pxAQKYCWNuczuv1usm0ntdqpSs57LvyuxXahAguymMyIoWHU__96GZaEWuVfFrpkz__tetFAQZtotgeGlAE7OAOgGMYRHpc12gud5AK_iaV4If_CpD4ymrGZGv_EvcTcNeiyj9GPLkh54cKc5AH3uHcjR0mttbpVDWhqb_C4cciwKv1YczqGwAKsNOLZTzj1hs-hws7m5pY1TVuIW8WXWL-2nYS4FM9U/download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.24.200, 107.152.25.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.24.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘GeoCord.csv’
#
# GeoCord.csv         100%[=====================>]   2.82K  --.-KB/s   in 0s
#
# 2019-01-03 07:45:48 (49.5 MB/s) - ‘GeoCord.csv’ saved [2891/2891]

# %%
df_cord = pd.read_csv('GeoCord.csv') # Read the csv data
df_cord.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# Create Latitude and Longitude columns in df_assigned
df_assigned['Latitude'] = np.nan
df_assigned['Longitude'] = np.nan

# For each postcode in df_assigned, find corresponding coordinates in df_cord and assign it to df_assigned
for idx in df_assigned.index:
    cord_idx = df_cord['Postal Code'] == df_assigned.loc[idx, 'Postcode']
    df_assigned.at[idx, 'Latitude'] = df_cord.loc[cord_idx, 'Latitude'].values
    df_assigned.at[idx, 'Longitude'] = df_cord.loc[cord_idx, 'Longitude'].values

# Display the results
df_assigned.head(20)
# Out:
#    Postcode      Borough                                      Neighbourhood  \
# 0       M1B  Scarborough                                     Malvern, Rouge
# 1       M1C  Scarborough             Highland Creek, Rouge Hill, Port Union
# 2       M1E  Scarborough                  Morningside, Guildwood, West Hill
# 3       M1G  Scarborough                                             Woburn
# 4       M1H  Scarborough                                          Cedarbrae
# 5       M1J  Scarborough                                Scarborough Village
# 6       M1K  Scarborough        Ionview, Kennedy Park, East Birchmount Park
# 7       M1L  Scarborough                    Golden Mile, Clairlea, Oakridge
# 8       M1M  Scarborough    Cliffside, Scarborough Village West, Cliffcrest
# 9       M1N  Scarborough                        Cliffside West, Birch Cliff
# 10      M1P  Scarborough  Scarborough Town Centre, Wexford Heights, Dors...
# 11      M1R  Scarborough                                  Wexford, Maryvale
# 12      M1S  Scarborough                                          Agincourt
# 13      M1T  Scarborough            Sullivan, Clarks Corners, Tam O'Shanter
# 14      M1V  Scarborough  Agincourt North, Steeles East, L'Amoreaux East...
# 15      M1W  Scarborough                      L'Amoreaux West, Steeles West
# 16      M1X  Scarborough                                        Upper Rouge
# 17      M2H   North York                                  Hillcrest Village
# 18      M2J   North York                       Fairview, Oriole, Henry Farm
# 19      M2K   North York                                    Bayview Village
#
#      Latitude  Longitude
# 0   43.806686 -79.194353
# 1   43.784535 -79.160497
# 2   43.763573 -79.188711
# 3   43.770992 -79.216917
# 4   43.773136 -79.239476
# 5   43.744734 -79.239476
# 6   43.727929 -79.262029
# 7   43.711112 -79.284577
# 8   43.716316 -79.239476
# 9   43.692657 -79.264848
# 10  43.757410 -79.273304
# 11  43.750072 -79.295849
# 12  43.794200 -79.262029
# 13  43.781638 -79.304302
# 14  43.815252 -79.284577
# 15  43.799525 -79.318389
# 16  43.836125 -79.205636
# 17  43.803762 -79.363452
# 18  43.778517 -79.346556
# 19  43.786947 -79.385975
